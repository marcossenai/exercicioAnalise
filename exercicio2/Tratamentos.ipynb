# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_excel('faltas_treinamento_sujo.xlsx')
display(df.head(20))
# Out:
#                Nome Departamento  Turno  Faltas Dia_da_Semana_Ultima_Falta  \
# 0   Colaborador_001    Operações  Manhã      14                     Quarta
# 1   Colaborador_002    Operações  Manhã       1                    Segunda
# 2   Colaborador_003       Vendas  Manhã       3                    segunda
# 3   Colaborador_004    Marketing  manha       3                    Segunda
# 4   Colaborador_005           RH  manha       1                     Quarta
# 5   Colaborador_006           RH  manha       2                    segunda
# 6   Colaborador_007    Marketing  Manhã       1                    segunda
# 7   Colaborador_008    Operações  Manhã      11                      Terça
# 8   Colaborador_009   Financeiro  TARDE       2                    segunda
# 9   Colaborador_010           TI  manha       2                    segunda
# 10  Colaborador_011       Vendas  Tarde       1                     Quinta
# 11  Colaborador_012           TI  manha       0                    Segunda
# 12  Colaborador_013    Marketing  manha       4                      Sexta
# 13  Colaborador_014    Marketing  TARDE       2                    segunda
# 14  Colaborador_015    Operações  manha       1                     Quinta
# 15  Colaborador_016           TI  TARDE       3                    Segunda
# 16  Colaborador_017    Operações  TARDE       2                     Quinta
# 17  Colaborador_018       Vendas  Manhã       6                    Segunda
# 18  Colaborador_019    Operações  manha       1                     Quinta
# 19  Colaborador_020    Operações  manha       1                      Terça
#
#    Data_Ultima_Falta Evadiu
# 0         18/01/2024    Sim
# 1         31/02/2024    Não
# 2         10/03/2024    Não
# 3         21/01/2024    Não
# 4         18/02/2024    Não
# 5         16/01/2024    Não
# 6         16/02/2024    Não
# 7         11/01/2024    Sim
# 8         21/01/2024    Não
# 9         18/03/2024    Não
# 10        22/03/2024    Não
# 11        05/01/2024    Não
# 12        10/02/2024    Não
# 13        03/02/2024    Não
# 14        21/02/2024    Não
# 15        20/01/2024    Não
# 16        29/02/2024    Não
# 17        09/03/2024    Sim
# 18        01/01/2024    Não
# 19        14/01/2024    Não

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Nome                        224 non-null    object
#  1   Departamento                224 non-null    object
#  2   Turno                       224 non-null    object
#  3   Faltas                      224 non-null    int64
#  4   Dia_da_Semana_Ultima_Falta  224 non-null    object
#  5   Data_Ultima_Falta           224 non-null    object
#  6   Evadiu                      210 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 12.4+ KB
# None

# %%
#correção de datas

df['Data_Ultima_Falta'] = pd.to_datetime(df['Data_Ultima_Falta'], format='%d/%m/%Y', errors='coerce')
display(df, df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224 entries, 0 to 223
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Nome                        224 non-null    object
#  1   Departamento                224 non-null    object
#  2   Turno                       224 non-null    object
#  3   Faltas                      224 non-null    int64
#  4   Dia_da_Semana_Ultima_Falta  224 non-null    object
#  5   Data_Ultima_Falta           212 non-null    datetime64[ns]
#  6   Evadiu                      210 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 12.4+ KB
#                 Nome Departamento  Turno  Faltas Dia_da_Semana_Ultima_Falta  \
# 0    Colaborador_001    Operações  Manhã      14                     Quarta
# 1    Colaborador_002    Operações  Manhã       1                    Segunda
# 2    Colaborador_003       Vendas  Manhã       3                    segunda
# 3    Colaborador_004    Marketing  manha       3                    Segunda
# 4    Colaborador_005           RH  manha       1                     Quarta
# ..               ...          ...    ...     ...                        ...
# 219  Colaborador_056    Operações  Tarde       2                    segunda
# 220  Colaborador_102       Vendas  manha       3                    segunda
# 221  Colaborador_188       Vendas  Manhã       3                    segunda
# 222  Colaborador_147    Marketing  Tarde       1                    segunda
# 223  Colaborador_092       Vendas  Manhã       0                     Quinta
#
#     Data_Ultima_Falta Evadiu
# 0          2024-01-18    Sim
# 1                 NaT    Não
# 2          2024-03-10    Não
# 3          2024-01-21    Não
# 4          2024-02-18    Não
# ..                ...    ...
# 219        2024-01-05    Não
# 220        2024-02-15    Não
# 221        2024-02-04    NaN
# 222        2024-02-02    Não
# 223        2024-01-09    Não
#
# [224 rows x 7 columns]
# None

# %%
#correção de nomes

df['Turno'] = df['Turno'].str.strip().str.lower().str.title().replace({'Manha': 'Manhã'})

df['Dia_da_Semana_Ultima_Falta'] = df['Dia_da_Semana_Ultima_Falta'].str.strip().str.lower().str.title()

display(df)
# Out:
#                 Nome Departamento  Turno  Faltas Dia_da_Semana_Ultima_Falta  \
# 0    Colaborador_001    Operações  Manhã      14                     Quarta
# 1    Colaborador_002    Operações  Manhã       1                    Segunda
# 2    Colaborador_003       Vendas  Manhã       3                    Segunda
# 3    Colaborador_004    Marketing  Manhã       3                    Segunda
# 4    Colaborador_005           RH  Manhã       1                     Quarta
# ..               ...          ...    ...     ...                        ...
# 219  Colaborador_056    Operações  Tarde       2                    Segunda
# 220  Colaborador_102       Vendas  Manhã       3                    Segunda
# 221  Colaborador_188       Vendas  Manhã       3                    Segunda
# 222  Colaborador_147    Marketing  Tarde       1                    Segunda
# 223  Colaborador_092       Vendas  Manhã       0                     Quinta
#
#     Data_Ultima_Falta Evadiu
# 0          2024-01-18    Sim
# 1                 NaT    Não
# 2          2024-03-10    Não
# 3          2024-01-21    Não
# 4          2024-02-18    Não
# ..                ...    ...
# 219        2024-01-05    Não
# 220        2024-02-15    Não
# 221        2024-02-04    NaN
# 222        2024-02-02    Não
# 223        2024-01-09    Não
#
# [224 rows x 7 columns]

# %%
# remove duplicados 

display(df[df.duplicated(keep=False)])

df = df.drop_duplicates()
# Out:
#                 Nome Departamento  Turno  Faltas Dia_da_Semana_Ultima_Falta  \
# 55   Colaborador_056    Operações  Tarde       2                    Segunda
# 91   Colaborador_092       Vendas  Manhã       0                     Quinta
# 101  Colaborador_102       Vendas  Manhã       3                    Segunda
# 146  Colaborador_147    Marketing  Tarde       1                    Segunda
# 187  Colaborador_188       Vendas  Manhã       3                    Segunda
# 219  Colaborador_056    Operações  Tarde       2                    Segunda
# 220  Colaborador_102       Vendas  Manhã       3                    Segunda
# 221  Colaborador_188       Vendas  Manhã       3                    Segunda
# 222  Colaborador_147    Marketing  Tarde       1                    Segunda
# 223  Colaborador_092       Vendas  Manhã       0                     Quinta
#
#     Data_Ultima_Falta Evadiu
# 55         2024-01-05    Não
# 91         2024-01-09    Não
# 101        2024-02-15    Não
# 146        2024-02-02    Não
# 187        2024-02-04    NaN
# 219        2024-01-05    Não
# 220        2024-02-15    Não
# 221        2024-02-04    NaN
# 222        2024-02-02    Não
# 223        2024-01-09    Não

# %%
#substituir 'evadiu' por 'desconhecido'
df['Evadiu'] = df['Evadiu'].fillna('desconhecido')
display(df[70:90])
# Out:
#                Nome Departamento  Turno  Faltas Dia_da_Semana_Ultima_Falta  \
# 70  Colaborador_071    Operações  Tarde       1                      Terça
# 71  Colaborador_072   Financeiro  Tarde       1                    Segunda
# 72  Colaborador_073   Financeiro  Tarde       2                     Quinta
# 73  Colaborador_074    Marketing  Tarde       2                      Sexta
# 74  Colaborador_075    Marketing  Tarde       5                      Terça
# 75  Colaborador_076       Vendas  Tarde       1                     Quarta
# 76  Colaborador_077           RH  Manhã       2                    Segunda
# 77  Colaborador_078           TI  Tarde       4                     Quinta
# 78  Colaborador_079           TI  Tarde       1                      Sexta
# 79  Colaborador_080       Vendas  Tarde       2                     Quarta
# 80  Colaborador_081    Marketing  Tarde       1                     Quarta
# 81  Colaborador_082    Operações  Tarde       4                     Quinta
# 82  Colaborador_083    Marketing  Manhã       5                     Quinta
# 83  Colaborador_084           RH  Tarde       2                     Quinta
# 84  Colaborador_085    Marketing  Manhã       1                     Quinta
# 85  Colaborador_086           RH  Tarde       3                    Segunda
# 86  Colaborador_087           TI  Tarde       2                      Sexta
# 87  Colaborador_088   Financeiro  Tarde       5                     Quarta
# 88  Colaborador_089    Operações  Manhã       5                      Terça
# 89  Colaborador_090           RH  Tarde       5                    Segunda
#
#    Data_Ultima_Falta        Evadiu
# 70        2024-03-29  desconhecido
# 71        2024-01-07           Não
# 72        2024-03-12           Não
# 73        2024-01-21           Não
# 74        2024-02-05           Sim
# 75        2024-02-06           Não
# 76        2024-01-30           Não
# 77        2024-02-29           Não
# 78        2024-01-03           Não
# 79        2024-02-19           Não
# 80        2024-01-04           Não
# 81        2024-03-20           Não
# 82        2024-02-29           Sim
# 83        2024-02-18           Não
# 84               NaT           Não
# 85               NaT  desconhecido
# 86        2024-01-17           Não
# 87        2024-01-22           Sim
# 88        2024-01-14           Sim
# 89        2024-03-16           Sim

# %%
#substitui valores da data(Nat) por data mais comum
df['Data_Ultima_Falta'] = df['Data_Ultima_Falta'].fillna(df['Data_Ultima_Falta'].mode()[0])
display(df[70:90])
# Out:
#                Nome Departamento  Turno  Faltas Dia_da_Semana_Ultima_Falta  \
# 70  Colaborador_071    Operações  Tarde       1                      Terça
# 71  Colaborador_072   Financeiro  Tarde       1                    Segunda
# 72  Colaborador_073   Financeiro  Tarde       2                     Quinta
# 73  Colaborador_074    Marketing  Tarde       2                      Sexta
# 74  Colaborador_075    Marketing  Tarde       5                      Terça
# 75  Colaborador_076       Vendas  Tarde       1                     Quarta
# 76  Colaborador_077           RH  Manhã       2                    Segunda
# 77  Colaborador_078           TI  Tarde       4                     Quinta
# 78  Colaborador_079           TI  Tarde       1                      Sexta
# 79  Colaborador_080       Vendas  Tarde       2                     Quarta
# 80  Colaborador_081    Marketing  Tarde       1                     Quarta
# 81  Colaborador_082    Operações  Tarde       4                     Quinta
# 82  Colaborador_083    Marketing  Manhã       5                     Quinta
# 83  Colaborador_084           RH  Tarde       2                     Quinta
# 84  Colaborador_085    Marketing  Manhã       1                     Quinta
# 85  Colaborador_086           RH  Tarde       3                    Segunda
# 86  Colaborador_087           TI  Tarde       2                      Sexta
# 87  Colaborador_088   Financeiro  Tarde       5                     Quarta
# 88  Colaborador_089    Operações  Manhã       5                      Terça
# 89  Colaborador_090           RH  Tarde       5                    Segunda
#
#    Data_Ultima_Falta        Evadiu
# 70        2024-03-29  desconhecido
# 71        2024-01-07           Não
# 72        2024-03-12           Não
# 73        2024-01-21           Não
# 74        2024-02-05           Sim
# 75        2024-02-06           Não
# 76        2024-01-30           Não
# 77        2024-02-29           Não
# 78        2024-01-03           Não
# 79        2024-02-19           Não
# 80        2024-01-04           Não
# 81        2024-03-20           Não
# 82        2024-02-29           Sim
# 83        2024-02-18           Não
# 84        2024-03-20           Não
# 85        2024-03-20  desconhecido
# 86        2024-01-17           Não
# 87        2024-01-22           Sim
# 88        2024-01-14           Sim
# 89        2024-03-16           Sim

# %%
#convertendo 'faltas'
df['Faltas'] = df['Faltas'].astype(int)
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 219 entries, 0 to 218
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Nome                        219 non-null    object
#  1   Departamento                219 non-null    object
#  2   Turno                       219 non-null    object
#  3   Faltas                      219 non-null    int64
#  4   Dia_da_Semana_Ultima_Falta  219 non-null    object
#  5   Data_Ultima_Falta           219 non-null    datetime64[ns]
#  6   Evadiu                      219 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 13.7+ KB
# None

# %%
# Calcular limites para detectar outliers
q1 = df['Faltas'].quantile(0.25)
q3 = df['Faltas'].quantile(0.75)
iqr = q3 - q1
limite_inf = q1 - 1.5 * iqr
limite_sup = q3 + 1.5 * iqr

# Substituir outliers por NaN
df.loc[(df['Faltas'] < limite_inf) | (df['Faltas'] > limite_sup), 'Faltas'] = np.nan

# Substituir NaN pela mediana
df['Faltas'] = df['Faltas'].fillna(df['Faltas'].median())

# %%
#Cria um flag “Faltas_Suspeitas” para valores &gt; 10.
df['Faltas_Suspeitas'] = df['Faltas'] > 10
display(df[df['Faltas_Suspeitas'] == True])
# Out:
# Empty DataFrame
# Columns: [Nome, Departamento, Turno, Faltas, Dia_da_Semana_Ultima_Falta, Data_Ultima_Falta, Evadiu, Faltas_Suspeitas]
# Index: []
